# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

# %%
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %% [markdown]
# #### Random Forest

# %%
# Initialize the Random Forest regressor
rf_regressor = RandomForestRegressor(random_state=42)

# Train the Random Forest model on the training data
rf_regressor.fit(X_train, y_train)

# Predict housing prices on the testing data
y_pred = rf_regressor.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Display evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 146853874475275.56
# Mean Absolute Error (MAE): 4142213.1730717863

# %% [markdown]
# #### Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# Define the hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 150],  # Number of trees in the forest
    'max_depth': [None, 10, 20],      # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4]     # Minimum number of samples required to be at a leaf node
}

# Initialize the Random Forest regressor
rf_regressor = RandomForestRegressor(random_state=42)

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', verbose=2)

# Perform grid search to find the best hyperparameters
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Use the best model for prediction
best_rf_model = grid_search.best_estimator_
y_pred = best_rf_model.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE) on Test Set:", mse)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  26.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  26.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  25.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  24.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  31.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 1.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 1.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 1.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 1.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time= 1.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time= 1.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time= 1.7min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time= 1.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time= 1.9min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  29.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  24.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  20.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  20.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  22.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  41.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  41.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  43.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  41.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  43.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time= 1.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time= 1.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time= 1.2min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time= 1.3min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time= 1.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  20.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  26.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  24.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  22.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  22.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  47.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  45.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  44.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  45.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  45.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time= 1.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time= 1.1min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time= 1.0min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time= 1.4min
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time= 1.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  22.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  21.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  21.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  22.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=  23.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  39.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  39.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  37.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  35.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  37.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time= 1.0min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time= 1.3min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time= 1.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time= 1.1min
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=  57.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  18.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  17.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  19.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  17.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=  19.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  36.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  35.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  37.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  36.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  38.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  55.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  54.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  54.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  54.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  55.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  15.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  17.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  16.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  16.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  16.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  33.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  31.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  34.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  32.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  33.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  49.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  45.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  47.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  47.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  47.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  14.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  13.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  14.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  14.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  14.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  28.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  28.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  28.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  28.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  28.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  42.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  42.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  44.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  41.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  43.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=  14.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=  14.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=  14.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=  13.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=  13.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  28.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  27.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  27.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  28.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  28.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  43.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  42.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  41.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  45.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  46.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  14.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  14.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  13.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  15.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  15.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  29.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  30.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  29.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  31.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  28.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  43.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  41.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  43.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  42.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  41.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  12.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  11.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  11.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=  11.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  23.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  33.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  34.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  33.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  34.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  33.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  11.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  22.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=